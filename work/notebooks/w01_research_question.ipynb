# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Himanshu-rai-prog/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
""" My Lane: Search Ranking and Discoverability

I chose the Search Ranking and Discoverability lane because I want to understand how search data can help improve website performance. My goal is to analyze search metrics such as impressions, clicks, CTR, and average position to find useful patterns that can support better SEO decisions.
"""
# Out:
# ' My Lane: Search Ranking and Discoverability\n\nI chose the Search Ranking and Discoverability lane because I want to understand how search data can help improve website performance. My goal is to analyze search metrics such as impressions, clicks, CTR, and average position to find useful patterns that can support better SEO decisions.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""Research Question

How can search performance metrics such as impressions, clicks, CTR, and average position help identify pages that should be optimized?

Decision: Identify which pages need SEO improvement.

Action: The SEO team updates page content, titles, and keywords.

Cost of a wrong call: Time and effort may be wasted on pages that do not need improvement, while important pages continue to lose traffic.
"""
# Out:
# 'Research Question\n\nHow can search performance metrics such as impressions, clicks, CTR, and average position help identify pages that should be optimized?\n\nDecision: Identify which pages need SEO improvement.\n\nAction: The SEO team updates page content, titles, and keywords.\n\nCost of a wrong call: Time and effort may be wasted on pages that do not need improvement, while important pages continue to lose traffic.\n'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Quick Look at the Data

The dataset contains search performance metrics such as impressions, clicks, CTR, and average position. Pages with higher impressions generally receive more clicks. CTR varies depending on the average position, and pages with better rankings often have higher CTR. These observations suggest that search metrics can help identify pages that may benefit from SEO improvements.
"""
# Out:
# '### Quick Look at the Data\n\nThe dataset contains search performance metrics such as impressions, clicks, CTR, and average position. Pages with higher impressions generally receive more clicks. CTR varies depending on the average position, and pages with better rankings often have higher CTR. These observations suggest that search metrics can help identify pages that may benefit from SEO improvements.\n'

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Careful Words

This analysis can identify patterns and relationships in search performance data. It can support SEO decisions and highlight pages that may need improvement. However, it does not prove causation or explain Google's ranking algorithm.
"""
# Out:
# "### Careful Words\n\nThis analysis can identify patterns and relationships in search performance data. It can support SEO decisions and highlight pages that may need improvement. However, it does not prove causation or explain Google's ranking algorithm.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
