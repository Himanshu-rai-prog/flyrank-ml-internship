# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Himanshu-rai-prog/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
### ML Task Type

"""My lane is a **Ranking** task. The goal is to rank web pages based on their search performance so that the best optimization opportunities are identified first."""
# Out:
# 'My lane is a **Ranking** task. The goal is to rank web pages based on their search performance so that the best optimization opportunities are identified first.'

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Target or Proxy

The target is to predict which pages need SEO improvement. I will use search metrics such as impressions, clicks, CTR, and average position as the proxy."""
# Out:
# '### Target or Proxy\n\nThe target is to predict which pages need SEO improvement. I will use search metrics such as impressions, clicks, CTR, and average position as the proxy.'

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Success Metric

The model will be successful if it correctly identifies high-priority pages for optimization with at least **80% accuracy**."""
# Out:
# '### Success Metric\n\nThe model will be successful if it correctly identifies high-priority pages for optimization with at least **80% accuracy**.'

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Unit of Analysis

Each row in the dataset represents **one web page** with its search performance metrics such as impressions, clicks, CTR, and average position."""
# Out:
# '### Unit of Analysis\n\nEach row in the dataset represents **one web page** with its search performance metrics such as impressions, clicks, CTR, and average position.'

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""### Why ML Beats a Fixed Rule

Search performance depends on many factors that change over time. Machine Learning can learn patterns from multiple features, while a fixed rule cannot handle complex relationships effectively."""
# Out:
# '### Why ML Beats a Fixed Rule\n\nSearch performance depends on many factors that change over time. Machine Learning can learn patterns from multiple features, while a fixed rule cannot handle complex relationships effectively.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
